# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # A1  Q1

# %%
df=pd.ExcelFile('Lab Session1 Data.xlsx')
df.sheet_names
df=pd.read_excel('Lab Session1 Data.xlsx',sheet_name='Purchase data')
df.head()
# Out:
#   Customer  Candies (#)  Mangoes (Kg)  Milk Packets (#)  Payment (Rs)  \
# 0      C_1           20             6                 2           386
# 1      C_2           16             3                 6           289
# 2      C_3           27             6                 2           393
# 3      C_4           19             1                 2           110
# 4      C_5           24             4                 2           280
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# 1         NaN         NaN         NaN         NaN         NaN  ...
# 2         NaN         NaN         NaN         NaN         NaN  ...
# 3         NaN         NaN         NaN         NaN         NaN  ...
# 4         NaN         NaN         NaN         NaN         NaN  ...
#
#    Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 17  Unnamed: 18  Candy  Mango  Milk
# 0          NaN          NaN    1.0   55.0  18.0
# 1          NaN          NaN    NaN    NaN   NaN
# 2          NaN          NaN    NaN    NaN   NaN
# 3          NaN          NaN    NaN    NaN   NaN
# 4          NaN          NaN    NaN    NaN   NaN
#
# [5 rows x 22 columns]

# %%
A=df.iloc[:,1:4]
print(A)
C=df.iloc[:,4:5]
print(C)
# Out:
#    Candies (#)  Mangoes (Kg)  Milk Packets (#)
# 0           20             6                 2
# 1           16             3                 6
# 2           27             6                 2
# 3           19             1                 2
# 4           24             4                 2
# 5           22             1                 5
# 6           15             4                 2
# 7           18             4                 2
# 8           21             1                 4
# 9           16             2                 4
#    Payment (Rs)
# 0           386
# 1           289
# 2           393
# 3           110
# 4           280
# 5           167
# 6           271
# 7           274
# 8           148
# 9           198

# %% [markdown]
# # Q1

# %%
df.shape
# Out:
# (10, 22)

# %%
df.shape[0]
# Out:
# 10

# %%
print("A's rank",np.linalg.matrix_rank(A))
print("C's rank",np.linalg.matrix_rank(C))
# Out:
# A's rank 3
# C's rank 1

# %% [markdown]
# # A 2

# %%
x=np.linalg.pinv(A)
# A(pseudo)=(A^T*A)^-1*A^T
# C(pseudo)=(C^T*C)^-1*C^T

#  X=A^+ * C
z=np.dot(x,C)
print(z)
# Out:
# [[ 1.]
#  [55.]
#  [18.]]

# %% [markdown]
# # A3

# %%
def rich_poor(pay):
    if pay>200:
        return "RICH"
    else:
        return "POOR"
df['RICH OR POOR'] = df['Payment (Rs)'].apply(rich_poor)
df[['Customer','Candies (#)','Mangoes (Kg)','Milk Packets (#)','Payment (Rs)','RICH OR POOR']]
# Out:
#   Customer  Candies (#)  Mangoes (Kg)  Milk Packets (#)  Payment (Rs)  \
# 0      C_1           20             6                 2           386
# 1      C_2           16             3                 6           289
# 2      C_3           27             6                 2           393
# 3      C_4           19             1                 2           110
# 4      C_5           24             4                 2           280
# 5      C_6           22             1                 5           167
# 6      C_7           15             4                 2           271
# 7      C_8           18             4                 2           274
# 8      C_9           21             1                 4           148
# 9     C_10           16             2                 4           198
#
#   RICH OR POOR
# 0         RICH
# 1         RICH
# 2         RICH
# 3         POOR
# 4         RICH
# 5         POOR
# 6         RICH
# 7         RICH
# 8         POOR
# 9         POOR

# %% [markdown]
# # A4

# %%
df1=pd.read_excel("Lab Session1 Data.xlsx",sheet_name='IRCTC Stock Price')
df1
# Out:
#              Date Month  Day    Price     Open     High      Low   Volume  \
# 0    Jun 29, 2021   Jun  Tue  2081.85  2092.00  2126.90  2065.05    1.67M
# 1    Jun 28, 2021   Jun  Mon  2077.75  2084.00  2112.45  2068.40  707.73K
# 2    Jun 25, 2021   Jun  Fri  2068.85  2084.35  2088.50  2053.10  475.82K
# 3    Jun 24, 2021   Jun  Thu  2072.95  2098.00  2098.00  2066.00  541.51K
# 4    Jun 23, 2021   Jun  Wed  2078.25  2102.00  2111.40  2072.00  809.62K
# ..            ...   ...  ...      ...      ...      ...      ...      ...
# 244  Jul 07, 2020   Jul  Tue  1397.40  1410.00  1411.00  1390.05  480.21K
# 245  Jul 06, 2020   Jul  Mon  1400.75  1405.50  1415.50  1394.00  614.93K
# 246  Jul 03, 2020   Jul  Fri  1405.10  1415.00  1425.00  1398.00  599.49K
# 247  Jul 02, 2020   Jul  Thu  1412.35  1440.00  1467.80  1395.30    2.16M
# 248  Jul 01, 2020   Jul  Wed  1363.05  1363.65  1377.00  1356.00  383.00K
#
#        Chg%
# 0    0.0020
# 1    0.0043
# 2   -0.0020
# 3   -0.0026
# 4   -0.0023
# ..      ...
# 244 -0.0024
# 245 -0.0031
# 246 -0.0051
# 247  0.0362
# 248  0.0032
#
# [249 rows x 9 columns]

# %%
x=df1.iloc[:,4]
x
# Out:
# 0      2092.00
# 1      2084.00
# 2      2084.35
# 3      2098.00
# 4      2102.00
#         ...
# 244    1410.00
# 245    1405.50
# 246    1415.00
# 247    1440.00
# 248    1363.65
# Name: Open, Length: 249, dtype: float64

# %%
print("mean",x.mean())
print("median",x.median())
# Out:
# mean 1560.9654618473896
# median 1440.0

# %%
df1.head()
# Out:
#            Date Month  Day    Price     Open     High      Low   Volume  \
# 0  Jun 29, 2021   Jun  Tue  2081.85  2092.00  2126.90  2065.05    1.67M
# 1  Jun 28, 2021   Jun  Mon  2077.75  2084.00  2112.45  2068.40  707.73K
# 2  Jun 25, 2021   Jun  Fri  2068.85  2084.35  2088.50  2053.10  475.82K
# 3  Jun 24, 2021   Jun  Thu  2072.95  2098.00  2098.00  2066.00  541.51K
# 4  Jun 23, 2021   Jun  Wed  2078.25  2102.00  2111.40  2072.00  809.62K
#
#      Chg%
# 0  0.0020
# 1  0.0043
# 2 -0.0020
# 3 -0.0026
# 4 -0.0023

# %%
df1[df1['Day']=='Wed'].get('Price').mean()
# Out:
# 1550.7060000000001

# %%
x=pd.read_excel("Lab Session1 Data.xlsx",sheet_name='IRCTC Stock Price')
x
# Out:
#              Date Month  Day    Price     Open     High      Low   Volume  \
# 0    Jun 29, 2021   Jun  Tue  2081.85  2092.00  2126.90  2065.05    1.67M
# 1    Jun 28, 2021   Jun  Mon  2077.75  2084.00  2112.45  2068.40  707.73K
# 2    Jun 25, 2021   Jun  Fri  2068.85  2084.35  2088.50  2053.10  475.82K
# 3    Jun 24, 2021   Jun  Thu  2072.95  2098.00  2098.00  2066.00  541.51K
# 4    Jun 23, 2021   Jun  Wed  2078.25  2102.00  2111.40  2072.00  809.62K
# ..            ...   ...  ...      ...      ...      ...      ...      ...
# 244  Jul 07, 2020   Jul  Tue  1397.40  1410.00  1411.00  1390.05  480.21K
# 245  Jul 06, 2020   Jul  Mon  1400.75  1405.50  1415.50  1394.00  614.93K
# 246  Jul 03, 2020   Jul  Fri  1405.10  1415.00  1425.00  1398.00  599.49K
# 247  Jul 02, 2020   Jul  Thu  1412.35  1440.00  1467.80  1395.30    2.16M
# 248  Jul 01, 2020   Jul  Wed  1363.05  1363.65  1377.00  1356.00  383.00K
#
#        Chg%
# 0    0.0020
# 1    0.0043
# 2   -0.0020
# 3   -0.0026
# 4   -0.0023
# ..      ...
# 244 -0.0024
# 245 -0.0031
# 246 -0.0051
# 247  0.0362
# 248  0.0032
#
# [249 rows x 9 columns]

# %%
x.mean()
# Out:
# C:\Users\naman\AppData\Local\Temp\ipykernel_42576\3791599204.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   x.mean()
# Price    1560.663454
# Open     1560.965462
# High     1586.130522
# Low      1538.742771
# Chg%        0.001964
# dtype: float64

# %%
a_data = df1[df1['Month'] == 'Apr']
a_mean = a_data['Price'].mean()
a_mean
# COMpare
population_price_mean = df1['Price'].mean()
population_price_mean
# Out:
# 1550.7060000000001

# %%
LOSS = a_data['Chg%'].apply(lambda x: 1 if x < 0 else 0).mean()
LOSS
# Out:
# 0.0
